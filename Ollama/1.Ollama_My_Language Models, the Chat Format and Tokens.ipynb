# %%
import ollama

# %%
def get_completion(prompt, model="llama3.1"):
    response = ollama.chat(model=model, messages=[{"role": "user", "content": prompt}])
    return response['message']['content']

# %%
response = get_completion("What is the capital of France?")
print(response)
# Out:
# The capital of France is Paris.

# %%
response = get_completion("Take the letters in lollipop and reverse them")
print(response)
# Out:
# The letters in "lollipop" spelled backwards are: pppololl.

# %%
response = get_completion("Take the letters in l-o-l-l-i-p-o-p and reverse them")
print(response)
# Out:
# The reversed letters are: p-o-p-i-l-o-l.

# %%
def get_completion_from_messages(messages, model="llama3.1"):
    response = ollama.chat(model=model, messages=messages)
    return response['message']['content']

# %%
messages = [
    {'role': 'system', 'content': "You are an assistant who responds in the style of Dr Seuss."},
    {'role': 'user', 'content': "Write me a very short poem about a happy carrot"}
]

response = get_completion_from_messages(messages)
print(response)
# Out:
# Here is a little ditty with flair:
#
# In the garden, so bright and bold,
# Lived a happy carrot, young and old.
# It danced in the sun with gleeful zest,
# A joyful orange, it loved to rest!

# %%
# Length restriction example
messages = [
    {'role': 'system', 'content': 'All your responses must be one sentence long.'},
    {'role': 'user', 'content': 'Write me a story about a happy carrot'},
]
response = get_completion_from_messages(messages)
print(response)
# Out:
# The little orange carrot, named Carl, lived in a sunny garden filled with vibrant flowers and spent his days basking in the warm rays of sunshine that made him feel happy and content.

# %%
# Combined example
messages = [
    {'role': 'system', 'content': """You are an assistant who responds in the style of Dr Seuss.
    All your responses must be one sentence long."""},
    {'role': 'user', 'content': "Write me a story about a happy carrot"}
]
response = get_completion_from_messages(messages)
print(response)
# Out:
# In the garden of glee, grew a carrot so bright and free, named Carlotta, who danced with joy every single day with gleeful ease!

# %%
def get_completion_and_token_count(messages, model="llama3"):
    response = ollama.chat(model=model, messages=messages)
    
    # Ollama does not return exact token counts, so we estimate
    formatted_prompt = "\n".join([msg["content"] for msg in messages])
    
    token_dict = {
        'prompt_tokens': len(formatted_prompt.split()),  # Approximate count
        'completion_tokens': len(response['message']['content'].split()),
        'total_tokens': len(formatted_prompt.split()) + len(response['message']['content'].split()),
    }

    return response['message']['content'], token_dict

# %%
messages = [
    {'role': 'system', 'content': "You are an assistant who responds in the style of Dr Seuss."},
    {'role': 'user', 'content': "Write me a very short poem about a happy carrot"}
]

response, token_dict = get_completion_and_token_count(messages)

print("Response:", response)
print("Token Usage:", token_dict)
# Out:
# Response: In the garden, oh so bright,
# Grew a carrot with pure delight!
# It danced and twirled with gleeful grin,
# A happy veggie, full of joy within!
#
# Its orange hue shone like the sun,
# As it laughed and played, having fun!
# This cheerful carrot, full of zest,
# Was the happiest in the garden nest!
# Token Usage: {'prompt_tokens': 22, 'completion_tokens': 53, 'total_tokens': 75}
