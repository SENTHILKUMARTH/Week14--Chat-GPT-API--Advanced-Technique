# %%
import ollama

# %%
def get_completion_from_messages(messages, model="llama3.1", temperature=0):
    # Combine all messages into a single formatted string
    combined_text = "\n".join([msg["content"] for msg in messages])

    # Generate response using Ollama's Llama 3 model
    response = ollama.chat(model=model, messages=[{"role": "user", "content": combined_text}])
    
    return response['message']['content']  # Extract response text

# %%
# Define delimiter
delimiter = "####"

# System instructions embedded inside the user query
system_message = f"""
Follow these steps to answer the customer queries.
The customer query will be delimited with four hashtags, i.e. {delimiter}. 

Step 1:{delimiter} First decide whether the user is asking a question about a specific product or products. 
Product category doesn't count. 

Step 2:{delimiter} If the user is asking about specific products, identify whether the products are in the following list.
All available products: 
1. Product: TechPro Ultrabook - Price: $799.99
2. Product: BlueWave Gaming Laptop - Price: $1199.99
3. Product: PowerLite Convertible - Price: $699.99
4. Product: TechPro Desktop - Price: $999.99
5. Product: BlueWave Chromebook - Price: $249.99

Step 3:{delimiter} If the message contains products in the list above, list any assumptions that the user is making in their message.

Step 4:{delimiter} If the user made any assumptions, figure out whether the assumption is true based on your product information. 

Step 5:{delimiter} First, politely correct the customer's incorrect assumptions if applicable. 
Only mention or reference products in the list of 5 available products, as these are the only 5 products that the store sells. 
Answer the customer in a friendly tone.

Use the following format:
Step 1:{delimiter} <step 1 reasoning>
Step 2:{delimiter} <step 2 reasoning>
Step 3:{delimiter} <step 3 reasoning>
Step 4:{delimiter} <step 4 reasoning>
Response to user:{delimiter} <response to customer>

Make sure to include {delimiter} to separate every step.
"""

# %%
# User query
user_message = f"""
by how much is the BlueWave Chromebook more expensive \
than the TechPro Desktop
"""

# Formatting messages
messages = [  
    {'role': 'user', 'content': f"{delimiter}{system_message}{delimiter}\n{user_message}{delimiter}"}
] 

# Get response from Ollama (Llama 3)
response = get_completion_from_messages(messages)
print(response)
# Out:
# #### Step 1: The user is asking a question about specific products, as they are mentioning two product names.
#
# #### Step 2: Yes, both the BlueWave Chromebook and the TechPro Desktop are in the list of available products.
#
# #### Step 3: It appears that the user assumes that these two products are comparable in terms of functionality or purpose, but this assumption is not explicitly stated.
#
# #### Step 4: The BlueWave Chromebook is a budget-friendly option ($249.99) and is designed for basic tasks such as browsing, email, and word processing, whereas the TechPro Desktop is a more powerful device with a higher price point ($999.99). However, this comparison does not directly address the user's question.
#
# #### Step 5: Response to user:
# Hi there! I see what you're asking, but just to clarify, the BlueWave Chromebook and TechPro Desktop are quite different in terms of their design and functionality. The BlueWave Chromebook is a lightweight, budget-friendly option for basic tasks, while the TechPro Desktop is a more powerful machine that's better suited for heavier use like gaming or video editing. To answer your question directly: the TechPro Desktop is actually significantly more expensive than the BlueWave Chromebook - it's about $750 more!

# %%
# User query
user_message = "do you sell TVs"

# Formatting messages
messages = [  
    {'role': 'user', 'content': f"{delimiter}{system_message}{delimiter}\n{user_message}{delimiter}"}
] 

# Get response from Ollama (Llama 3)
response = get_completion_from_messages(messages)
print(response)
# Out:
# Step 1:#### The customer is not asking a question about specific products.
#
# Step 2:#### This query does not contain any products from the list of available products (TechPro Ultrabook, BlueWave Gaming Laptop, PowerLite Convertible, TechPro Desktop, and BlueWave Chromebook).
#
# Step 3:#### There are no assumptions made in this message that need to be addressed.
#
# Step 4:#### No action is needed based on the customer's query as it does not reference any products we sell.
#
# Response to user:#### Hi there! We actually don't have TVs for sale at our store. However, we do carry a variety of laptops and desktops from top brands like TechPro and BlueWave that might interest you. Would you like me to recommend some options?

# %%
try:
    final_response = response.split(delimiter)[-1].strip()
except Exception as e:
    final_response = "Sorry, I'm having trouble right now, please try asking another question."
    
print(final_response)
# Out:
# Hi there! We actually don't have TVs for sale at our store. However, we do carry a variety of laptops and desktops from top brands like TechPro and BlueWave that might interest you. Would you like me to recommend some options?
