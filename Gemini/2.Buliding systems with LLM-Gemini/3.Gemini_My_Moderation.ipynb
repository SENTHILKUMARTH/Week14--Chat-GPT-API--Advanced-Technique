# %%
from google import genai

client = genai.Client(api_key="AIzaSyChigI6fNmpI0XYkFgbNgJk8qnGK3H7s5g")

# %%
model="gemini-2.5-flash"
from google.genai import types

# %%
def get_completion_from_messages(messages,
                                 model=model,
                                 temperature=0,
                                 max_tokens=500):
   
    response = client.models.generate_content(
        model=model,
        contents=messages,
        config=types.GenerateContentConfig(
            temperature=temperature,
            max_output_tokens=max_tokens,
        )
    )
    print('response.text', response)
    return response.text

# %%
# Call the moderation-like function
def moderation_check(input_text):
    print(input_text)
    messages = [
        "You are a content moderation AI. Reply with 'Safe' if the input is appropriate, otherwise reply with 'Flagged'.",
        input_text
    ]
    return get_completion_from_messages(messages, max_tokens=10)  # Call Gemini model

# Example moderation check
response = moderation_check("""
Here's the plan. We get the warhead,
and we hold the world ransom...
...FOR ONE MILLION DOLLARS!
""")

print(response)  # Expected output: "Flagged" or "Safe"
# Out:
# Here's the plan. We get the warhead,
# and we hold the world ransom...
# ...FOR ONE MILLION DOLLARS!
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[35], line 11
#       8     return get_completion_from_messages(messages, max_tokens=10)  # Call Gemini model
#      10 # Example moderation check
# ---> 11 response = moderation_check("""
#      12 Here's the plan. We get the warhead,
#      13 and we hold the world ransom...
#      14 ...FOR ONE MILLION DOLLARS!
#      15 """)
#      17 print(response)  # Expected output: "Flagged" or "Safe"
#
# Cell In[35], line 8, in moderation_check(input_text)
#       3 print(input_text)
#       4 messages = [
#       5     "You are a content moderation AI. Reply with 'Safe' if the input is appropriate, otherwise reply with 'Flagged'.",
#       6     input_text
#       7 ]
# ----> 8 return get_completion_from_messages(messages, max_tokens=10)
#
# Cell In[34], line 6, in get_completion_from_messages(messages, model, temperature, max_tokens)
#       1 def get_completion_from_messages(messages,
#       2                                  model=model,
#       3                                  temperature=0,
#       4                                  max_tokens=500):
# ----> 6     response = client.models.generate_content(
#       7         model=model,
#       8         contents=messages,
#       9         config=types.GenerateContentConfig(
#      10             temperature=temperature,
#      11             max_output_tokens=max_tokens,
#      12         )
#      13     )
#      14     print('response.text', response)
#      15     return response.text
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\models.py:5621, in Models.generate_content(self, model, contents, config)
#    5619 while remaining_remote_calls_afc > 0:
#    5620   i += 1
# -> 5621   response = self._generate_content(
#    5622       model=model, contents=contents, config=parsed_config
#    5623   )
#    5625   function_map = _extra_utils.get_function_map(parsed_config)
#    5626   if not function_map:
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\models.py:4283, in Models._generate_content(self, model, contents, config)
#    4280 request_dict = _common.convert_to_dict(request_dict)
#    4281 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4283 response = self._api_client.request(
#    4284     'post', path, request_dict, http_options
#    4285 )
#    4287 if config is not None and getattr(
#    4288     config, 'should_return_http_response', None
#    4289 ):
#    4290   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\_api_client.py:1396, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1386 def request(
#    1387     self,
#    1388     http_method: str,
#    (...)
#    1391     http_options: Optional[HttpOptionsOrDict] = None,
#    1392 ) -> SdkHttpResponse:
#    1393   http_request = self._build_request(
#    1394       http_method, path, request_dict, http_options
#    1395   )
# -> 1396   response = self._request(http_request, http_options, stream=False)
#    1397   response_body = (
#    1398       response.response_stream[0] if response.response_stream else ''
#    1399   )
#    1400   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\_api_client.py:1232, in BaseApiClient._request(self, http_request, http_options, stream)
#    1229     retry = tenacity.Retrying(**retry_kwargs)
#    1230     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1232 return self._retry(self._request_once, http_request, stream)
#
# File ~\.conda\envs\gemini_env\lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~\.conda\envs\gemini_env\lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\.conda\envs\gemini_env\lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~\.conda\envs\gemini_env\lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\.conda\envs\gemini_env\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\.conda\envs\gemini_env\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~\.conda\envs\gemini_env\lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\_api_client.py:1209, in BaseApiClient._request_once(self, http_request, stream)
#    1201 else:
#    1202   response = self._httpx_client.request(
#    1203       method=http_request.method,
#    1204       url=http_request.url,
#    (...)
#    1207       timeout=http_request.timeout,
#    1208   )
# -> 1209   errors.APIError.raise_for_response(response)
#    1210   return HttpResponse(
#    1211       response.headers, response if stream else [response.text]
#    1212   )
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~\.conda\envs\gemini_env\lib\site-packages\google\genai\errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)
#     156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 5.768936299s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '5s'}]}}
