# %%
from google import genai

client = genai.Client(api_key="AIzaSyBTs9dGBas4TFElo29J1OAXygLjYVfZfL0")

# Initialize conversation
system_msg = input("What type of chatbot would you like to create?\n")

print("Your new assistant is ready")


# Start chatbot loop
while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    # Send user input directly (Gemini does not use "role")
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user_input
    )

    # Extract response
    reply = response.text

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  Mental Health Chatbot
# Your new assistant is ready
#  ok
# Okay. What can I help you with?
#  Need some real time example
# "Real-time" in the context of computing and data generally refers to systems that process information and respond to events almost instantaneously, or within a very short, specific, and predictable timeframe, often measured in milliseconds.
#
# Here are some real-time examples you encounter daily:
#
# 1.  **Online Chat and Messaging Apps:**
#     *   **Example:** WhatsApp, Slack, Telegram, Facebook Messenger, iMessage.
#     *   **Why real-time?** When you send a message, you expect it to be delivered and visible to the recipient immediately. You see "typing..." indicators, read receipts, and online/offline statuses updated as they happen. A delay would make conversation unnatural.
#
# 2.  **Video Conferencing and Voice Calls:**
#     *   **Example:** Zoom, Google Meet, Microsoft Teams, FaceTime.
#     *   **Why real-time?** For a natural conversation, audio and video must be synchronized and transmitted with extremely low latency. Any significant delay (lag) makes it difficult to communicate effectively.
#
# 3.  **Live Sports Scores and News Feeds:**
#     *   **Example:** ESPN app, BBC News Live, stock market tickers.
#     *   **Why real-time?** Fans want immediate updates on scores, player statistics, and critical game events. Financial traders need up-to-the-second stock prices to make decisions. News organizations use it for breaking news alerts.
#
# 4.  **Online Multiplayer Gaming:**
#     *   **Example:** Fortnite, Call of Duty, League of Legends, Apex Legends.
#     *   **Why real-time?** Every player's action (moving, shooting, using abilities) must be registered and reflected for all other players instantly. High latency ("lag") makes the game unplayable and unfair.
#
# 5.  **GPS Navigation with Live Traffic Updates:**
#     *   **Example:** Google Maps, Waze.
#     *   **Why real-time?** Your location is tracked and updated in real-time on the map. Traffic conditions are gathered from other users and updated constantly, allowing the app to suggest alternative routes to avoid delays *as they happen*.
#
# 6.  **Collaborative Document Editing:**
#     *   **Example:** Google Docs, Microsoft 365 (Word Online, Excel Online).
#     *   **Why real-time?** When multiple people edit a document simultaneously, you can see other users' cursors, what they are typing, and changes they make as they happen, preventing conflicts and fostering seamless collaboration.
#
# 7.  **Credit Card and Mobile Payment Processing:**
#     *   **Example:** Swiping your credit card, using Apple Pay or Google Pay at a store.
#     *   **Why real-time?** The system needs to instantly communicate with your bank to verify funds and authorize the transaction, typically within seconds, to complete the purchase at the point of sale.
#
# 8.  **Industrial Control Systems (ICS) and SCADA:**
#     *   **Example:** Controlling robots on an assembly line, monitoring power grids, managing water treatment plants.
#     *   **Why real-time?** These systems require immediate processing of sensor data and instant execution of commands to maintain safety, efficiency, and prevent catastrophic failures. A delay of even milliseconds can be critical.
#
# 9.  **Self-Driving Cars:**
#     *   **Example:** Tesla Autopilot, Waymo.
#     *   **Why real-time?** These vehicles must process massive amounts of sensor data (cameras, radar, lidar) in milliseconds to detect objects, predict movements, make driving decisions, and react to the environment instantly to ensure safety.
#
# 10. **Live Streaming (Video/Audio):**
#     *   **Example:** Twitch, YouTube Live, Instagram Live.
#     *   **Why real-time?** The content is broadcast as it's being captured, allowing viewers to experience events as they unfold and interact with the streamer or other viewers via live chat.
#
# These examples highlight how real-time processing is crucial for responsiveness, interactivity, and safety in many modern applications and systems.
#  world cup t20 super eight 2026
# Yes, the Super Eight stage is expected to be a key part of the ICC Men's T20 World Cup 2026, which will be co-hosted by **India and Sri Lanka**.
#
# Based on the format introduced for the 2024 edition, it is highly anticipated that the 2026 tournament will follow a similar structure:
#
# 1.  **Initial Group Stage:**
#     *   20 teams will likely be divided into four groups of five.
#     *   Each team plays the other teams in its group once.
#
# 2.  **Qualification for Super Eight:**
#     *   The top two teams from each of the four initial groups will advance to the Super Eight stage. This means 8 teams in total.
#
# 3.  **Super Eight Stage:**
#     *   These eight qualified teams will then be split into two groups of four.
#     *   Each team in a Super Eight group plays the other teams in its group once.
#
# 4.  **Path to Semifinals:**
#     *   The top two teams from each of the two Super Eight groups will then progress to the semifinals.
#
# This Super Eight format ensures that the top teams play more meaningful matches against each other before the direct knockout semifinals, adding an exciting and competitive layer to the tournament.
#
# While the official schedule, exact groupings, and specific venues will be announced by the ICC closer to the tournament date, this format is widely expected.
#  quit

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Give me 3 AI SaaS ideas"
)
